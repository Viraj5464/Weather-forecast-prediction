# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("Weather forecast dataset.csv")

# %%
data
# Out:
#                  date_time  maxtempC  mintempC  totalSnow_cm  sunHour  \
# 0      2009-01-01 00:00:00        24        10           0.0      8.7
# 1      2009-01-01 01:00:00        24        10           0.0      8.7
# 2      2009-01-01 02:00:00        24        10           0.0      8.7
# 3      2009-01-01 03:00:00        24        10           0.0      8.7
# 4      2009-01-01 04:00:00        24        10           0.0      8.7
# ...                    ...       ...       ...           ...      ...
# 96427  2020-01-01 19:00:00        15        11           0.0      7.1
# 96428  2020-01-01 20:00:00        15        11           0.0      7.1
# 96429  2020-01-01 21:00:00        15        11           0.0      7.1
# 96430  2020-01-01 22:00:00        15        11           0.0      7.1
# 96431  2020-01-01 23:00:00        15        11           0.0      7.1
#
#        uvIndex  uvIndex.1  moon_illumination  moonrise   moonset  ...  \
# ...

# %%
data[0:]
# Out:
#                  date_time  maxtempC  mintempC  totalSnow_cm  sunHour  \
# 0      2009-01-01 00:00:00        24        10           0.0      8.7
# 1      2009-01-01 01:00:00        24        10           0.0      8.7
# 2      2009-01-01 02:00:00        24        10           0.0      8.7
# 3      2009-01-01 03:00:00        24        10           0.0      8.7
# 4      2009-01-01 04:00:00        24        10           0.0      8.7
# ...                    ...       ...       ...           ...      ...
# 96427  2020-01-01 19:00:00        15        11           0.0      7.1
# 96428  2020-01-01 20:00:00        15        11           0.0      7.1
# 96429  2020-01-01 21:00:00        15        11           0.0      7.1
# 96430  2020-01-01 22:00:00        15        11           0.0      7.1
# 96431  2020-01-01 23:00:00        15        11           0.0      7.1
#
#        uvIndex  uvIndex.1  moon_illumination  moonrise   moonset  ...  \
# ...

# %%
data.corr()
# Out:
#                    maxtempC  mintempC  totalSnow_cm   sunHour   uvIndex  \
# maxtempC           1.000000  0.881495           NaN  0.785929  0.945121
# mintempC           0.881495  1.000000           NaN  0.744942  0.913161
# totalSnow_cm            NaN       NaN           NaN       NaN       NaN
# sunHour            0.785929  0.744942           NaN  1.000000  0.754874
# uvIndex            0.945121  0.913161           NaN  0.754874  1.000000
# uvIndex.1          0.241188  0.217436           NaN  0.194483  0.233236
# moon_illumination -0.027165 -0.016930           NaN -0.024647 -0.022649
# DewPointC          0.142769  0.469920           NaN  0.242303  0.225289
# FeelsLikeC         0.817037  0.873623           NaN  0.705933  0.820046
# HeatIndexC         0.816059  0.872525           NaN  0.704134  0.819260
# WindChillC         0.873654  0.837802           NaN  0.690558  0.855363
# WindGustKmph       0.053844  0.067802           NaN  0.106486  0.037093
# ...

# %%
data.describe()
# Out:
#            maxtempC      mintempC  totalSnow_cm       sunHour       uvIndex  \
# count  96432.000000  96432.000000       96432.0  96432.000000  96432.000000
# mean      33.400199     22.374564           0.0     11.037805      6.877053
# std        6.994211      7.635253           0.0      2.152973      1.551294
# min       15.000000      3.000000           0.0      4.000000      3.000000
# 25%       28.000000     16.000000           0.0      8.700000      6.000000
# 50%       34.000000     24.000000           0.0     11.600000      7.000000
# 75%       38.000000     28.000000           0.0     13.000000      8.000000
# max       51.000000     39.000000           0.0     13.900000     11.000000
#
#           uvIndex.1  moon_illumination     DewPointC    FeelsLikeC  \
# count  96432.000000       96432.000000  96432.000000  96432.000000
# mean       4.465012          46.094077     13.230629     30.735783
# std        3.414374          31.249725      8.053778      9.320398
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96432 entries, 0 to 96431
# Data columns (total 25 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date_time          96432 non-null  object
#  1   maxtempC           96432 non-null  int64
#  2   mintempC           96432 non-null  int64
#  3   totalSnow_cm       96432 non-null  float64
#  4   sunHour            96432 non-null  float64
#  5   uvIndex            96432 non-null  int64
#  6   uvIndex.1          96432 non-null  int64
#  7   moon_illumination  96432 non-null  int64
#  8   moonrise           96432 non-null  object
#  9   moonset            96432 non-null  object
#  10  sunrise            96432 non-null  object
#  11  sunset             96432 non-null  object
#  12  DewPointC          96432 non-null  int64
#  13  FeelsLikeC         96432 non-null  int64
#  14  HeatIndexC         96432 non-null  int64
#  15  WindChillC         96432 non-null  int64
# ...

# %%
data.plot()
# Out:
# <AxesSubplot:>

# %%
y=data["tempC"]

# %%
x=data[["maxtempC","mintempC","totalSnow_cm","sunHour","uvIndex","uvIndex.1","moon_illumination","DewPointC","FeelsLikeC","HeatIndexC","WindChillC","WindGustKmph","cloudcover","humidity","precipMM","pressure","visibility","winddirDegree","windspeedKmph"]]

# %%
y
# Out:
# 0        11
# 1        11
# 2        11
# 3        10
# 4        11
#          ..
# 96427    13
# 96428    13
# 96429    13
# 96430    13
# 96431    12
# Name: tempC, Length: 96432, dtype: int64

# %%
x
# Out:
#        maxtempC  mintempC  totalSnow_cm  sunHour  uvIndex  uvIndex.1  \
# 0            24        10           0.0      8.7        4          1
# 1            24        10           0.0      8.7        4          1
# 2            24        10           0.0      8.7        4          1
# 3            24        10           0.0      8.7        4          1
# 4            24        10           0.0      8.7        4          1
# ...         ...       ...           ...      ...      ...        ...
# 96427        15        11           0.0      7.1        4          1
# 96428        15        11           0.0      7.1        4          1
# 96429        15        11           0.0      7.1        4          1
# 96430        15        11           0.0      7.1        4          1
# 96431        15        11           0.0      7.1        4          1
#
#        moon_illumination  DewPointC  FeelsLikeC  HeatIndexC  WindChillC  \
# ...

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=124)

# %%
x_train
# Out:
#        maxtempC  mintempC  totalSnow_cm  sunHour  uvIndex  uvIndex.1  \
# 69919        25        12           0.0      8.7        5          5
# 7193         29        15           0.0      8.7        6          6
# 3379         45        33           0.0     13.3        9          1
# 64206        44        29           0.0     13.1        9          9
# 4347         43        34           0.0     13.9        9          1
# ...         ...       ...           ...      ...      ...        ...
# 84800        30        26           0.0     11.9        7          6
# 74690        37        28           0.0     13.8        8          1
# 90247        35        27           0.0     12.9        8          7
# 79889        23        14           0.0      4.2        5          4
# 70094        22        10           0.0      8.7        4          5
#
#        moon_illumination  DewPointC  FeelsLikeC  HeatIndexC  WindChillC  \
# ...

# %%
y_train
# Out:
# 69919    19
# 7193     20
# 3379     37
# 64206    36
# 4347     34
#          ..
# 84800    28
# 74690    30
# 90247    29
# 79889    20
# 70094    17
# Name: tempC, Length: 77145, dtype: int64

# %%
x_test
# Out:
#        maxtempC  mintempC  totalSnow_cm  sunHour  uvIndex  uvIndex.1  \
# 63327        35        19           0.0     11.6        7          8
# 88671        27        13           0.0      8.7        6          7
# 93416        36        28           0.0     10.6        7          7
# 74462        37        31           0.0     11.0        8          7
# 88578        26        16           0.0      8.7        5          6
# ...         ...       ...           ...      ...      ...        ...
# 23845        33        25           0.0     12.5        7          8
# 11913        45        27           0.0     13.2        9         10
# 46706        45        29           0.0     13.1        9          1
# 52908        21         8           0.0      8.7        4          6
# 36462        29        16           0.0     11.6        6          5
#
#        moon_illumination  DewPointC  FeelsLikeC  HeatIndexC  WindChillC  \
# ...

# %%
y_test
# Out:
# 63327    32
# 88671    26
# 93416    32
# 74462    33
# 88578    20
#          ..
# 23845    32
# 11913    45
# 46706    30
# 52908    21
# 36462    20
# Name: tempC, Length: 19287, dtype: int64

# %%
lr.fit(x_train,y_train)
# Out:
# C:\Users\viraj\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
pred=lr.predict(x_test)

# %%
pred
# Out:
# array([41, 22, 32, ..., 38, 21, 13], dtype=int64)

# %%
plt.scatter(y_test,pred)

# %%
from sklearn import metrics

# %%
print("MAE: ",metrics.mean_absolute_error(pred,y_test))
print("MSE: ",metrics.mean_squared_error(pred,y_test))
print("RMSE: ",metrics.mean_squared_error(pred,y_test)**0.5)
# Out:
# MAE:  2.7444911080002075
# MSE:  13.054544511847359
# RMSE:  3.6131073208316633

# %%
sns.displot(y_test-pred,bins=50)

# %%
from sklearn.linear_model import LinearRegression

# %%
L=LinearRegression()

# %%
L.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred1=L.predict(x_test)

# %%
pred1
# Out:
# array([32.2342621 , 22.86324673, 32.17421825, ..., 31.90495408,
#        20.81735316, 19.98690279])

# %%
y_test
# Out:
# 63327    32
# 88671    26
# 93416    32
# 74462    33
# 88578    20
#          ..
# 23845    32
# 11913    45
# 46706    30
# 52908    21
# 36462    20
# Name: tempC, Length: 19287, dtype: int64

# %%
print("MAE: ",metrics.mean_absolute_error(pred1,y_test))
print("MSE: ",metrics.mean_squared_error(pred1,y_test))
print("RMSE: ",metrics.mean_squared_error(pred1,y_test)**0.5)
# Out:
# MAE:  0.8271059940464056
# MSE:  1.236456015881373
# RMSE:  1.1119604380918293

# %%
plt.scatter(y_test,pred1)

# %%
sns.displot(y_test-pred1,bins=50)

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dtr=DecisionTreeRegressor()

# %%
dtr.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
pred2=dtr.predict(x_test)

# %%
pred2
# Out:
# array([32., 26., 32., ..., 29., 21., 20.])

# %%
y_test
# Out:
# 63327    32
# 88671    26
# 93416    32
# 74462    33
# 88578    20
#          ..
# 23845    32
# 11913    45
# 46706    30
# 52908    21
# 36462    20
# Name: tempC, Length: 19287, dtype: int64

# %%
print("MAE: ",metrics.mean_absolute_error(pred2,y_test))
print("MSE: ",metrics.mean_squared_error(pred2,y_test))
print("RMSE: ",metrics.mean_squared_error(pred2,y_test)**0.5)
# Out:
# MAE:  0.4450666251879504
# MSE:  0.7901695442526053
# RMSE:  0.8889148127085099

# %%
sns.displot(y_test-pred2,bins=50)

# %%
plt.scatter(y_test,pred2)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfg=RandomForestRegressor()

# %%
rfg.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
pred3=dtr.predict(x_test)

# %%
pred3
# Out:
# array([32., 26., 32., ..., 29., 21., 20.])

# %%
print("MAE: ",metrics.mean_absolute_error(pred3,y_test))
print("MSE: ",metrics.mean_squared_error(pred3,y_test))
print("RMSE: ",metrics.mean_squared_error(pred3,y_test)**0.5)
# Out:
# MAE:  0.4450666251879504
# MSE:  0.7901695442526053
# RMSE:  0.8889148127085099

# %%
sns.displot(y_test-pred3,bins=50)

# %%
plt.scatter(y_test,pred3)
